# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# 2025-04-21 05:45:55.642799: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745214355.854484      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745214355.909044      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import warnings
import tensorflow as tf
from tensorflow.keras import mixed_precision
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Flatten, Dense, Concatenate, GlobalAveragePooling2D, Multiply, Reshape, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, DenseNet121, ResNet101
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import shutil
import os
import requests
import zipfile
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
# Out:
# 2025-04-21 08:12:26.341574: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745223146.566538      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745223146.627699      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Suppress warnings
warnings.filterwarnings("ignore")
mixed_precision.set_global_policy('mixed_float16')

# %%
# base_dir = "/kaggle/working/extracted_dataset/An India soyabean leaf dataset/Soyabean leaf/"
base_dir = "/kaggle/input/swedish_dataset"

# %%
# Get class names from the base directory

class_names = os.listdir(base_dir)

for class_name in class_names:
    class_path = os.path.join(base_dir, class_name)
    
    if os.path.isdir(class_path):
        print(class_name)
        subdirectories = os.listdir(class_path)
        
        for subdirectory in subdirectories:
            sub_path = os.path.join(class_path, subdirectory)
            
            if os.path.isdir(sub_path):
                print("  -",subdirectory)
# Out:
# Salix_aurita
# Sorbus_intermedia
# Salix_sinerea
# Tilia
# Sorbus_aucuparia
# Salix_alba_Sericea
# Ulmus_glabra
# Populus
# Fagus_silvatica
# Populus_tremula
# Alnus_incana
# Acer
# Betula_pubescens
# Quercus
# Ulmus_carpinifolia

# %%
# Plot the images

def find_images(directory):
    image_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tif')):  
                image_files.append(os.path.join(root, file))
    return image_files

def plot_random_images(base_dir, class_names, num_images=3):
    
    plt.figure(figsize=(15, 15))
    for class_name in class_names:
        class_path = os.path.join(base_dir, class_name)
        
        if os.path.isdir(class_path):
            images = find_images(class_path)
            random_images = random.sample(images, min(num_images, len(images)))  
            
            for i, img_path in enumerate(random_images):
                img = plt.imread(img_path) 
                plt.subplot(len(class_names), num_images, class_names.index(class_name) * num_images + i + 1)
                plt.imshow(img)
                plt.axis('off')
                plt.title(class_name)
    plt.tight_layout()
    plt.show()

# Call the function to plot images
plot_random_images(base_dir, class_names, num_images=3)

# %%
input_dir = base_dir
output_dir = '/kaggle/working/swedish_dataset'

if not os.path.exists(output_dir):
    shutil.copytree(input_dir, output_dir)
    print("Files copied successfully.")
# Out:
# Files copied successfully.

# %%
for class_dir in os.listdir(output_dir):
    class_path = os.path.join(output_dir, class_dir)
    
    if os.path.isdir(class_path):
        for sub_dir in os.listdir(class_path):
            sub_path = os.path.join(class_path, sub_dir)
            
            if os.path.isdir(sub_path):
                for file in os.listdir(sub_path):
                    file_path = os.path.join(sub_path, file)
                    if os.path.isfile(file_path):  
                        shutil.move(file_path, class_path)                
                os.rmdir(sub_path)

print("Flattening completed. All files are now in their respective main class directories.")
# Out:
# Flattening completed. All files are now in their respective main class directories.

# %%
try:
    import splitfolders
except ImportError:
    # !pip install split-folders
    try:
        import splitfolders
    except ImportError:
        print("Installation failed. Please check your environment and try again.")

splitfolders.ratio(output_dir, output='Image_dataset', seed=123, ratio=(0.7,0.2,0.1))
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 1125 files [00:10, 105.35 files/s]

# %%
output_dir = '/kaggle/working/swedish_dataset'

if os.path.exists(output_dir):
    shutil.rmtree(output_dir) 
    print(f"{output_dir} has been deleted.")
else:
    print(f"{output_dir} does not exist.")
# Out:
# /kaggle/working/swedish_dataset does not exist.

# %%
# Hyperparameters
batch_size = 64
input_shape = (224, 224, 3)
learning_rate = 1e-5

# %%
# Data augmentation for the training set only
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rotation_range=20,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Test set without data augmentation
test_datagen = ImageDataGenerator(rescale=1./255)

# Training set
train_set = train_datagen.flow_from_directory(
    "/kaggle/working/Image_dataset/train",
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical'
)

# Validation set
valid_set = test_datagen.flow_from_directory(
    "/kaggle/working/Image_dataset/val",
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical'
)

# Testing set
test_set = test_datagen.flow_from_directory(
    "/kaggle/working/Image_dataset/test",  
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False 
)
# Out:
# Found 780 images belonging to 15 classes.
# Found 225 images belonging to 15 classes.
# Found 120 images belonging to 15 classes.

# %%
# Define the Model Architecture
input_layer = Input(shape=input_shape)
vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
densenet_model = DenseNet121(weights='imagenet', include_top=False, input_shape=input_shape)
resnet_model = ResNet101(weights='imagenet', include_top=False, input_shape=input_shape)
# Out:
# I0000 00:00:1745223353.755073      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
def extract_features_with_reduction(model, inputs):
    features = model(inputs)
    features = GlobalAveragePooling2D()(features)
    features = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(features) 
    return features

# %%
# Extract and apply attention for each model
vgg_features = extract_features_with_reduction(vgg_model, input_layer)
densenet_features = extract_features_with_reduction(densenet_model, input_layer)
resnet_features = extract_features_with_reduction(resnet_model, input_layer)

# %%
# Feature extraction

# vgg_features = Flatten()(vgg_model(input_layer))
# densenet_features = GlobalAveragePooling2D()(densenet_model(input_layer))
# resnet_features = GlobalAveragePooling2D()(resnet_model(input_layer))

# %%
# Feature fusion or Concatenate features 
concatenated_features = Concatenate(axis=-1)([vgg_features, densenet_features, resnet_features])
reduced_features = Dense(1024, activation='relu', kernel_regularizer=l2(0.01))(concatenated_features)
reduced_features = BatchNormalization()(reduced_features)
reduced_features = Dropout(0.5)(reduced_features)

# %%
# Attention Mechanism
def attention_block(inputs):
    x = GlobalAveragePooling2D()(inputs)
    x = Dense(x.shape[-1], activation='relu')(x)
    x = Dense(x.shape[-1], activation='sigmoid')(x)
    return Multiply()([inputs, x])

attention_features = attention_block(Reshape((1, 1, reduced_features.shape[-1]))(reduced_features))
attention_features = Flatten()(attention_features)

# %%
# Fully Connected Layers (FC layer)
fc = Dense(512, activation='relu')(attention_features)
fc = Dropout(0.5)(fc) 
fc = Dense(256, activation='relu')(fc)
fc = Dropout(0.5)(fc)

# %%
# Output layer
output_layer = Dense(train_set.num_classes, activation='softmax', dtype='float32')(fc)

# %%
# Compile Model 

final_model = Model(inputs=input_layer, outputs=output_layer)
optimizer = Adam(learning_rate=learning_rate)

final_model.compile(
    loss='categorical_crossentropy', 
    optimizer=optimizer, 
    metrics=['accuracy']
)

# %%
# Callbacks for training
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True)

# %%
# Summary of Model
final_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ vgg16 (Functional)        │ (None, 7, 7, 512)      │     14,714,688 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ densenet121 (Functional)  │ (None, 7, 7, 1024)     │      7,037,504 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ resnet101 (Functional)    │ (None, 7, 7, 2048)     │     42,658,176 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 512)            │              0 │ vgg16[0][0]            │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1024)           │              0 │ densenet121[0][0]      │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 2048)           │              0 │ resnet101[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 512)            │        262,656 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 512)            │        524,800 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 512)            │      1,049,088 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 1536)           │              0 │ dense[0][0],           │
# │                           │                        │                │ dense_1[0][0],         │
# │                           │                        │                │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1024)           │      1,573,888 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 1024)           │          4,096 │ dense_3[0][0]          │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 1024)           │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 1024)     │              0 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1024)           │              0 │ reshape[0][0]          │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 1024)           │      1,049,600 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1024)           │      1,049,600 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 1, 1, 1024)     │              0 │ reshape[0][0],         │
# │                           │                        │                │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 1024)           │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 512)            │        524,800 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 512)            │              0 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 256)            │        131,328 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 256)            │              0 │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast_3 (Cast)             │ (None, 256)            │              0 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 15)             │          3,855 │ cast_3[0][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 70,584,079 (269.26 MB)
#  Trainable params: 70,393,039 (268.53 MB)
#  Non-trainable params: 191,040 (746.25 KB)

# %%
# Train Model
history = final_model.fit(
    train_set,
    validation_data=valid_set,
    epochs=80,
    batch_size=batch_size,
    callbacks=[reduce_lr, model_checkpoint]
)
# Out:
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745223613.815827     123 service.cc:148] XLA service 0x7d8070003ce0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745223613.816750     123 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745223637.468100     123 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1745223890.007266     123 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 790s 25s/step - accuracy: 0.1001 - loss: 35.6729 - val_accuracy: 0.0711 - val_loss: 35.0618 - learning_rate: 1.0000e-05
# Epoch 2/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.0643 - loss: 35.5747 - val_accuracy: 0.0667 - val_loss: 34.9752 - learning_rate: 1.0000e-05
# Epoch 3/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.0739 - loss: 35.4979 - val_accuracy: 0.0667 - val_loss: 34.9016 - learning_rate: 1.0000e-05
# Epoch 4/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.0870 - loss: 35.2197 - val_accuracy: 0.0844 - val_loss: 34.8088 - learning_rate: 1.0000e-05
# Epoch 5/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.0798 - loss: 35.0925 - val_accuracy: 0.0889 - val_loss: 34.7148 - learning_rate: 1.0000e-05
# Epoch 6/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.1178 - loss: 34.9499 - val_accuracy: 0.0844 - val_loss: 34.6222 - learning_rate: 1.0000e-05
# Epoch 7/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.1194 - loss: 34.7971 - val_accuracy: 0.1067 - val_loss: 34.5343 - learning_rate: 1.0000e-05
# Epoch 8/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.1084 - loss: 34.6934 - val_accuracy: 0.1911 - val_loss: 34.4386 - learning_rate: 1.0000e-05
# Epoch 9/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.1580 - loss: 34.3916 - val_accuracy: 0.2089 - val_loss: 34.3356 - learning_rate: 1.0000e-05
# Epoch 10/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.1982 - loss: 34.2528 - val_accuracy: 0.2800 - val_loss: 34.2283 - learning_rate: 1.0000e-05
# Epoch 11/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.2179 - loss: 34.1199 - val_accuracy: 0.3244 - val_loss: 34.0908 - learning_rate: 1.0000e-05
# Epoch 12/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.2432 - loss: 33.9609 - val_accuracy: 0.3067 - val_loss: 33.9529 - learning_rate: 1.0000e-05
# Epoch 13/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.2485 - loss: 33.8168 - val_accuracy: 0.3822 - val_loss: 33.8205 - learning_rate: 1.0000e-05
# Epoch 14/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.3060 - loss: 33.6577 - val_accuracy: 0.3733 - val_loss: 33.7294 - learning_rate: 1.0000e-05
# Epoch 15/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.2939 - loss: 33.5552 - val_accuracy: 0.5067 - val_loss: 33.5557 - learning_rate: 1.0000e-05
# Epoch 16/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.3622 - loss: 33.3667 - val_accuracy: 0.5778 - val_loss: 33.4137 - learning_rate: 1.0000e-05
# Epoch 17/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3532 - loss: 33.2425 - val_accuracy: 0.5200 - val_loss: 33.3244 - learning_rate: 1.0000e-05
# Epoch 18/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3947 - loss: 33.1080 - val_accuracy: 0.5778 - val_loss: 33.1549 - learning_rate: 1.0000e-05
# Epoch 19/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4242 - loss: 32.9260 - val_accuracy: 0.5289 - val_loss: 32.9605 - learning_rate: 1.0000e-05
# Epoch 20/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.4395 - loss: 32.8330 - val_accuracy: 0.6267 - val_loss: 32.8953 - learning_rate: 1.0000e-05
# Epoch 21/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4477 - loss: 32.7466 - val_accuracy: 0.7111 - val_loss: 32.7718 - learning_rate: 1.0000e-05
# Epoch 22/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.4375 - loss: 32.6077 - val_accuracy: 0.7289 - val_loss: 32.5920 - learning_rate: 1.0000e-05
# Epoch 23/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4905 - loss: 32.4615 - val_accuracy: 0.7644 - val_loss: 32.4707 - learning_rate: 1.0000e-05
# Epoch 24/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.5130 - loss: 32.3333 - val_accuracy: 0.7644 - val_loss: 32.3322 - learning_rate: 1.0000e-05
# Epoch 25/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.5268 - loss: 32.2395 - val_accuracy: 0.8044 - val_loss: 32.1657 - learning_rate: 1.0000e-05
# Epoch 26/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.5672 - loss: 32.1188 - val_accuracy: 0.7956 - val_loss: 32.0308 - learning_rate: 1.0000e-05
# Epoch 27/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.5798 - loss: 31.9547 - val_accuracy: 0.7867 - val_loss: 31.8806 - learning_rate: 1.0000e-05
# Epoch 28/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.5899 - loss: 31.8928 - val_accuracy: 0.7733 - val_loss: 31.7997 - learning_rate: 1.0000e-05
# Epoch 29/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.6054 - loss: 31.7877 - val_accuracy: 0.8267 - val_loss: 31.7426 - learning_rate: 1.0000e-05
# Epoch 30/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.6335 - loss: 31.6435 - val_accuracy: 0.8444 - val_loss: 31.5662 - learning_rate: 1.0000e-05
# Epoch 31/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.6283 - loss: 31.5889 - val_accuracy: 0.8578 - val_loss: 31.4187 - learning_rate: 1.0000e-05
# Epoch 32/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.6666 - loss: 31.4344 - val_accuracy: 0.8222 - val_loss: 31.3904 - learning_rate: 1.0000e-05
# Epoch 33/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.6964 - loss: 31.3129 - val_accuracy: 0.8222 - val_loss: 31.2445 - learning_rate: 1.0000e-05
# Epoch 34/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.7000 - loss: 31.2454 - val_accuracy: 0.8667 - val_loss: 31.1065 - learning_rate: 1.0000e-05
# Epoch 35/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.7021 - loss: 31.1315 - val_accuracy: 0.8578 - val_loss: 31.0669 - learning_rate: 1.0000e-05
# Epoch 36/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.6853 - loss: 31.0729 - val_accuracy: 0.8711 - val_loss: 30.9235 - learning_rate: 1.0000e-05
# Epoch 37/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.7296 - loss: 30.9530 - val_accuracy: 0.8578 - val_loss: 30.8491 - learning_rate: 1.0000e-05
# Epoch 38/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.7430 - loss: 30.8090 - val_accuracy: 0.8711 - val_loss: 30.7354 - learning_rate: 1.0000e-05
# Epoch 39/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.7699 - loss: 30.6707 - val_accuracy: 0.8622 - val_loss: 30.6836 - learning_rate: 1.0000e-05
# Epoch 40/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.7990 - loss: 30.5979 - val_accuracy: 0.9022 - val_loss: 30.5130 - learning_rate: 1.0000e-05
# Epoch 41/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.7922 - loss: 30.4626 - val_accuracy: 0.9244 - val_loss: 30.4051 - learning_rate: 1.0000e-05
# Epoch 42/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.8160 - loss: 30.4162 - val_accuracy: 0.9111 - val_loss: 30.3143 - learning_rate: 1.0000e-05
# Epoch 43/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.8046 - loss: 30.3093 - val_accuracy: 0.9289 - val_loss: 30.1904 - learning_rate: 1.0000e-05
# Epoch 44/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.8192 - loss: 30.2367 - val_accuracy: 0.9644 - val_loss: 30.0274 - learning_rate: 1.0000e-05
# Epoch 45/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8279 - loss: 30.0982 - val_accuracy: 0.9689 - val_loss: 29.9441 - learning_rate: 1.0000e-05
# Epoch 46/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.8139 - loss: 30.0589 - val_accuracy: 0.9689 - val_loss: 29.8530 - learning_rate: 1.0000e-05
# Epoch 47/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8040 - loss: 30.0099 - val_accuracy: 0.9556 - val_loss: 29.8017 - learning_rate: 1.0000e-05
# Epoch 48/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8575 - loss: 29.8308 - val_accuracy: 0.9467 - val_loss: 29.7202 - learning_rate: 1.0000e-05
# Epoch 49/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8700 - loss: 29.7468 - val_accuracy: 0.9778 - val_loss: 29.5843 - learning_rate: 1.0000e-05
# Epoch 50/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8875 - loss: 29.6755 - val_accuracy: 0.9689 - val_loss: 29.4917 - learning_rate: 1.0000e-05
# Epoch 51/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.8468 - loss: 29.6021 - val_accuracy: 0.9644 - val_loss: 29.4245 - learning_rate: 1.0000e-05
# Epoch 52/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.8664 - loss: 29.5478 - val_accuracy: 0.9689 - val_loss: 29.3182 - learning_rate: 1.0000e-05
# Epoch 53/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8842 - loss: 29.4337 - val_accuracy: 0.9778 - val_loss: 29.2132 - learning_rate: 1.0000e-05
# Epoch 54/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8966 - loss: 29.3054 - val_accuracy: 0.9733 - val_loss: 29.1865 - learning_rate: 1.0000e-05
# Epoch 55/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9338 - loss: 29.2067 - val_accuracy: 0.9733 - val_loss: 29.0816 - learning_rate: 1.0000e-05
# Epoch 56/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9175 - loss: 29.1552 - val_accuracy: 0.9733 - val_loss: 28.9657 - learning_rate: 1.0000e-05
# Epoch 57/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9080 - loss: 29.0849 - val_accuracy: 0.9822 - val_loss: 28.8301 - learning_rate: 1.0000e-05
# Epoch 58/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9168 - loss: 28.9973 - val_accuracy: 0.9733 - val_loss: 28.8119 - learning_rate: 1.0000e-05
# Epoch 59/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9188 - loss: 28.9291 - val_accuracy: 0.9778 - val_loss: 28.7160 - learning_rate: 1.0000e-05
# Epoch 60/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9048 - loss: 28.8566 - val_accuracy: 0.9689 - val_loss: 28.6650 - learning_rate: 1.0000e-05
# Epoch 61/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9193 - loss: 28.7592 - val_accuracy: 0.9778 - val_loss: 28.5376 - learning_rate: 1.0000e-05
# Epoch 62/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9287 - loss: 28.6585 - val_accuracy: 0.9778 - val_loss: 28.4556 - learning_rate: 1.0000e-05
# Epoch 63/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9475 - loss: 28.5799 - val_accuracy: 0.9822 - val_loss: 28.3655 - learning_rate: 1.0000e-05
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9188 - loss: 28.5628 - val_accuracy: 0.9822 - val_loss: 28.3110 - learning_rate: 1.0000e-05
# Epoch 65/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9238 - loss: 28.4776 - val_accuracy: 0.9778 - val_loss: 28.2505 - learning_rate: 1.0000e-05
# Epoch 66/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9377 - loss: 28.3715 - val_accuracy: 0.9733 - val_loss: 28.1530 - learning_rate: 1.0000e-05
# Epoch 67/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9489 - loss: 28.2887 - val_accuracy: 0.9733 - val_loss: 28.0619 - learning_rate: 1.0000e-05
# Epoch 68/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9496 - loss: 28.2086 - val_accuracy: 0.9778 - val_loss: 27.9960 - learning_rate: 1.0000e-05
# Epoch 69/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9619 - loss: 28.1371 - val_accuracy: 0.9867 - val_loss: 27.9362 - learning_rate: 1.0000e-05
# Epoch 70/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9330 - loss: 28.0971 - val_accuracy: 0.9867 - val_loss: 27.8563 - learning_rate: 1.0000e-05
# Epoch 71/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9406 - loss: 27.9997 - val_accuracy: 0.9867 - val_loss: 27.7913 - learning_rate: 1.0000e-05
# Epoch 72/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9623 - loss: 27.8999 - val_accuracy: 0.9911 - val_loss: 27.7075 - learning_rate: 1.0000e-05
# Epoch 73/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9433 - loss: 27.8633 - val_accuracy: 0.9911 - val_loss: 27.6416 - learning_rate: 1.0000e-05
# Epoch 74/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9605 - loss: 27.7609 - val_accuracy: 0.9867 - val_loss: 27.5569 - learning_rate: 1.0000e-05
# Epoch 75/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9742 - loss: 27.6753 - val_accuracy: 0.9867 - val_loss: 27.4874 - learning_rate: 1.0000e-05
# Epoch 76/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9613 - loss: 27.6274 - val_accuracy: 0.9867 - val_loss: 27.4238 - learning_rate: 1.0000e-05
# Epoch 77/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9407 - loss: 27.5734 - val_accuracy: 0.9911 - val_loss: 27.3476 - learning_rate: 1.0000e-05
# Epoch 78/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9526 - loss: 27.5372 - val_accuracy: 0.9911 - val_loss: 27.2743 - learning_rate: 1.0000e-05
# Epoch 79/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9730 - loss: 27.3986 - val_accuracy: 0.9956 - val_loss: 27.1910 - learning_rate: 1.0000e-05
# Epoch 80/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9657 - loss: 27.3554 - val_accuracy: 0.9956 - val_loss: 27.1227 - learning_rate: 1.0000e-05

# %%
# Evaluate the model on the validation set
val_labels = valid_set.classes  # True labels
val_predictions = final_model.predict(valid_set)
val_pred_classes = np.argmax(val_predictions, axis=1)  # Predicted labels

# Calculate and print classification report
print("Classification Report:")
print(classification_report(val_labels, val_pred_classes, target_names=list(valid_set.class_indices.keys())))

# Confusion Matrix
conf_matrix = confusion_matrix(val_labels, val_pred_classes)

# Plotting Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=valid_set.class_indices.keys(), yticklabels=valid_set.class_indices.keys())
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 50s 8s/step
# Classification Report:
#                     precision    recall  f1-score   support
#
#               Acer       0.33      0.33      0.33        15
#       Alnus_incana       0.13      0.13      0.13        15
#   Betula_pubescens       0.07      0.07      0.07        15
#    Fagus_silvatica       0.13      0.13      0.13        15
#            Populus       0.07      0.07      0.07        15
#    Populus_tremula       0.13      0.13      0.13        15
#            Quercus       0.07      0.07      0.07        15
# Salix_alba_Sericea       0.00      0.00      0.00        15
#       Salix_aurita       0.14      0.13      0.14        15
#      Salix_sinerea       0.00      0.00      0.00        15
#   Sorbus_aucuparia       0.00      0.00      0.00        15
#  Sorbus_intermedia       0.07      0.07      0.07        15
#              Tilia       0.20      0.20      0.20        15
# Ulmus_carpinifolia       0.19      0.20      0.19        15
#       Ulmus_glabra       0.13      0.13      0.13        15
#
#           accuracy                           0.11       225
#          macro avg       0.11      0.11      0.11       225
#       weighted avg       0.11      0.11      0.11       225

# %%
# # Load the best model
# final_model.load_weights('best_model.keras')

# %%
# # Save the final model
# model_path = '/kaggle/working/my_model.keras' 
# final_model.save(model_path)
# print(f"Final model saved at {model_path}")

# %%
# Plot Training and Validation Accuracy
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %%
# Plot Training and Validation Loss
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %%
# # Load the model
# model_path = '/kaggle/working/my_model.keras'
# final_model = load_model(model_path)
# print("Model loaded successfully.")

# %%
test_loss, test_accuracy = final_model.evaluate(test_set)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - accuracy: 0.9944 - loss: 27.1284
# Test Loss: 27.132917404174805
# Test Accuracy: 0.9916666746139526

# %%
predictions = final_model.predict(test_set)
predicted_classes = np.round(predictions).astype(int)  
print("Predicted Classes:", predicted_classes.flatten())
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Predicted Classes: [1 0 0 ... 0 0 1]

# %%
# Function to predict image class
def predict_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=input_shape[:2])
    img_array = tf.keras.preprocessing.image.img_to_array(img) / 255.0
    img_array = tf.expand_dims(img_array, axis=0)
    predictions = final_model.predict(img_array)
    predicted_class = tf.argmax(predictions[0]).numpy()
    predicted_label = total_classes[predicted_class]
    return predicted_label
